# %%
import urllib.request
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
import csv
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from ipywidgets import widgets, interactive
import time
import re

# %%
import plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

# %% [markdown]
# # Fire Emblem: Heroes Data Scraping

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project, we will be taking a look at character data from the popular mobile game *Fire Emblem: Heroes* available on iPhone and Android. Fire Emblem, a strategy RPG franchise developed by Intelligent System, added this mobile game to its list of entries following the popularity of recent titles *Fire Emblem: Awakening* and *Fire Emblem: Fates* for the 3DS. In this entry, you are in the position of a tactician, deploying up to four characters from the Fire Emblem Universe to do battle against the opposing enemy team. The game utilizes a rock-paper-scissors battle mechanic, with some weapons being superior to others.
#
# Like many popular mobile games, *Fire Emblem: Heroes* is a free-to-play Gacha game, where characters are drawn from a random pool, each with varying rarity and power.

# %% [markdown]
# ## Web-Scraping (Using Selenium)

# %% [markdown]
# We begin this project by obtaining the character data, using data hosted on gamepress.com (I do not own the data). A note before you ever webscrape, a helpful tip to know if you are allowed to scrape data from a web domain is to type _/robots.txt_ at the end of website link.
#
# For example, we will type:
# https://www.gamepress.com/robots.txt
#
# And we see that we have full access for scraping.
#
# If you need a reference for what the symbols on the robots.txt page, visit [this website](https://www.promptcloud.com/blog/how-to-read-and-respect-robots-file/):
#
# We will be utilizing a Python package called Selenium to assist us with web-scraping duties. We will use the package to help us obtain information regarding how the characters are rated according to GamePress. We will use this data later on to build a prediction model.
#
# To proceed, you will need to download a driver. I am using chrome, so I downloaded a chrome driver from [here](https://chromedriver.chromium.org/)

# %% [markdown]
# ### General Character Information
#
# We will start off by getting general character information, which includes their name, their stats, what type of weapon they use, what their character type, and their tier according to the GamePress Offensive Tier List.

# %%
ser = Service("./chromedriver")
op = webdriver.ChromeOptions()
browser = webdriver.Chrome(service=ser, options=op)

gg = "https://gamepress.gg/feheroes/heroes"
browser.get(gg)
respData = browser.page_source
browser.close()
nsoup = BeautifulSoup(respData, 'html.parser')
n_table = nsoup.find("table", id = "heroes-new-list")

# %%
gpress = []
hp = []
attack = []
speed = []
defense = []
res = []
total = []
color = []
weap = []
mov = []
rar = []
urls = []
other = []


for group in n_table.findAll("tr")[1::3]:
    #tier.append(group.findAll("td")[13].find(text = True))
    gpress.append(group.attrs.get("data-name"))
    hp.append(group.attrs.get("data-hp"))
    attack.append(group.attrs.get("data-atk"))
    speed.append(group.attrs.get("data-spd"))
    defense.append(group.attrs.get("data-def"))
    res.append(group.attrs.get("data-res"))
    total.append(group.attrs.get("data-total"))
    color.append(group.attrs.get("data-element").split()[0])
    weap.append(group.attrs.get("data-element").split()[-1])
    # data-cat-1="331" - infantry
    # data-cat-1="306" - cavalier
    # data-cat-1="326" - armor
    # data-cat-1="316" - flying
    mov.append(group.attrs.get("data-cat-1"))
    rar.append(group.attrs.get("data-stars"))
    
    link = group.findAll("td")[0].find("a")["href"]
    url = "https://gamepress.gg" + link
    urls.append(url)
    other.append(group.attrs.get("data-cat-"))

dfn = pd.DataFrame(gpress, columns = ["Name"])
#dfn["Tier"] = tier
dfn["Color"] = color
dfn["Weapon"] = weap
dfn["MoveCode"] = mov
dfn["Rarities"] = rar
dfn["HP"] = hp
dfn["Atk"] = attack
dfn["Spd"] = speed
dfn["Def"] = defense
dfn["Res"] = res
dfn["Total"] = total

# %%
dfn.head()
# Out:
#             Name  Color  Weapon MoveCode               Rarities  HP Atk Spd  \
# 0        Sharena   Blue   Lance      331           4_Star_Story  43  32  32
# 1  Flame Emperor  Green     Axe      326  3-4_Grand_Hero_Battle  50  40  25
# 2           Rath  Green     Bow      306                    3-4  41  33  35
# 3          Fiora   Blue   Lance      316           stars-5-Star  38  32  38
# 4          Leila   Gray  Dagger      331           stars-5-Star  40  36  41
#
#   Def Res Total
# 0  29  22   158
# 1  37  26   178
# 2  23  24   156
# 3  21  37   166
# 4  23  26   166

# %%
# for aether raids tier list - get href and tier 
ser = Service("./chromedriver")
op = webdriver.ChromeOptions()
# below two lines allow us to initiate "Headless Mode", which means that selenium works silently
op.add_argument('--headless')
op.add_argument('--disable-gpu')
browser = webdriver.Chrome(service=ser, options=op)
tlist = ("https://gamepress.gg/feheroes/aether-raids-tier-list")
browser.get(tlist)
tData = browser.page_source
browser.close()
tsoup = BeautifulSoup(tData, 'html.parser')

# %%
char_dict = {}
i = 0
for field in tsoup.find_all('div', attrs={'class':'field__item'}):
    if field.find('div', id=lambda x: x and x.startswith('tier-')):
        i += 1
        for in_tier in field.find_all('div', attrs = {'class': 'tier-list-cell-row'}):
            unit = in_tier.attrs.get("data-title")
            char_dict[unit] = int(i)
print("There are " + str(i) + " classes in this tier-list")
# Out:
# There are 5 classes in this tier-list

# %%
tiers = pd.DataFrame.from_dict(char_dict, orient = "index", columns = ["Tier"])
dfn = pd.merge(dfn, tiers, left_on = "Name", right_index = True, how = "left")

# %% [markdown]
# ### Specific Character Details
#
# What we will do next is to parse through each character's stat page on GamePress to grab information that we believe is useful to help predict a character's tier, along with other details which can serve a useful purpose for other projects.
#
# We currently grab the following details:
# * The tier itself
# * Game origin
# * Whether characater is a legendary hero
# * Whether character is a duo hero
# * Whether character can refine their weapon
# * Whether character has a unique weapon
# * Link for hero image
# * Character movement type
# * Banners in which the character shows up in
#
# NOTE: Running the cell below will take quite a lot of time (when I last ran it, it took >30 minutes. So have something to do while you wait - like playing Fire Emblem: Heroes.
#
# 10:13 - 11:48
# (as of now, the buffer alone is like 1.25 hours...)
#
# Link for limited: https://gamepress.gg/feheroes/limited

# %%
ser = Service("./chromedriver")
op = webdriver.ChromeOptions()
# below two lines allow us to initiate "Headless Mode", which means that selenium works silently
op.add_argument('--headless')
op.add_argument('--disable-gpu')
browser = webdriver.Chrome(service=ser, options=op)

all_char = []

for needed in urls:

    browser.get(needed)
    chardata = browser.page_source
    
    # has all of the html data
    soupy = BeautifulSoup(chardata, 'html.parser')
    all_char.append(soupy)
        
    # buffer for web driver
    time.sleep(4)
    
    #group.findAll("td")[12] is total
browser.quit()

# %%
title = []
for char in all_char:
    
    # get hero title
    char_title = ""
    for span in char.find("table", id = "hero-details-table").findAll("span"):
        char_title += span.text
    title.append(char_title)
dfn["Title"] = title

# %%
origin = []
for char in all_char:
    try:
        attempt_orig = char.find("div", {"class": 
         "field field--name-field-origin field--type-entity-reference field--label-hidden field__items"})
        games = attempt_orig.findAll("div", {"class": 'field__item'})
        if len(games) == 1:
            origin.append(games[0].text)
        else:
            game_lst = []
            for game in attempt_orig.findAll("div", {"class": 'field__item'}):
                game_lst.append(game.text)
            origin.append(game_lst)
    except AttributeError:
        origin.append("None")

dfn["Origin"] = origin

# %%
title = []
w_upgrades = []
personal = []
origin = []
img = []
is_legend = []
move_t = []
is_duo = []
col2 = []
weap2 = []
# below are new additions
tier = []
# banner can be a list to easily get banner count
banner = []
num_banner = []

for char in all_char:
    
    # get hero title
    char_title = ""
    for span in char.find("table", id = "hero-details-table").findAll("span"):
        char_title += span.text
    title.append(char_title)
    
    weapinfo = char.find("div", id = "weapon-skills")
    
    # retrieves whether the character has weapon-refines
    if weapinfo.findAll("div", {"id": "weapon-upgrades-section"})[0].find(
        "div", {"class": "view-content"}) is not None:
        w_upgrades.append(True)
    else:
        w_upgrades.append(False)

    # retrieves whether the character has a personal, non-inheritable weapon
    i = 0
    per = False
    for item in weapinfo.findAll("div", {"class": "views-element-container"
        })[0].findAll("tr"):
        if i == 0:
            i += 1
            continue
        if not item.findAll("div"):
            continue
        if "Non-Inheritable skill" in item.findAll("div")[-1].get_text():
            per = True
            break
    if per is False:
        personal.append(False)
    else:
        personal.append(True)

    # get origin information
    # need to start taking into account duos with origin of multiple games
    try:
        attempt_orig = char.find("div", {"class": 
         "field field--name-field-origin field--type-entity-reference field--label-hidden field__items"})
        games = attempt_orig.findAll("div", {"class": 'field__item'})
        if len(games) == 1:
            origin.append(games[0].text)
        else:
            game_lst = []
            for game in attempt_orig.findAll("div", {"class": 'field__item'}):
                game_lst.append(game.text)
            origin.append(game_lst)
    except AttributeError:
        origin.append(None)
        
    # get hero image link
    image = char.find("div", id = "hero-image").find("img")["src"]
    img.append("https://gamepress.gg" + image)

    att = char.find("div", id = "hero-atts")
    
    # get information about whether character is legendary/mythic
    is_legend.append(att.find("a", {"class": 
        "tipso-legendary"}) is not None)
    
    # get move type information
    move = att.find("div", {"class": 
        "field field--name-field-movement field--type-entity-reference field--label-hidden field__item"})
    move_t.append(move.get_text().replace("\n", "").replace(" ", ""))
    
    # get information about whether character is a duo character
    is_duo.append(char.find("div", {"class": "duo-skill-effect"}) is not None)
    
    # sanity check for color/weapon
    w_use = att.find("div", {"class": 
        "field field--name-field-attribute field--type-entity-reference field--label-hidden field__item"})
    colour, weapon = w_use.get_text().replace("\n", "").split()
    col2.append(colour)
    weap2.append(weapon)
    
    # get information regarding banners
    banner_h3 = char.find("h3", text="Banners Featured In")
    char_banner = []
    for row in banner_h3.find_next_siblings("div")[0].findAll('td'):
        char_banner.append(row.find("a").text)
    banner.append(char_banner)
    num_banner.append(len(char_banner))

# %%
dfn["Title"] = title
dfn["Refines"] = w_upgrades
dfn["Personal Weapon"] = personal
dfn["Legendary/Mythic"] = is_legend
dfn["Origin"] = origin
dfn["Duo"] = is_duo
dfn["Image"] = img
dfn["Movement"] = move_t
dfn["Banners"] = banner
dfn["Number of Banners"] = num_banner

# %% [markdown]
# If you looked carefully above, you may have noticed a "sanity check" that I put in. That is because there was an interesting discrepency that I noticed when trying to count up the units grouped by color and weapon. We will compare them below using the data from the general hero page and each hero's specific page:

# %%
dw = pd.DataFrame(col2, columns = ["Color"])
dw["Weapon"] = weap2

dw.groupby(by = ["Color", "Weapon"]).size()
# Out:
# Color  Weapon
# Blue   Beast       7
#        Bow         9
#        Dagger      5
#        Dragon     15
#        Lance     113
#        Tome       57
# Gray   Beast      10
#        Bow        49
#        Dagger     39
#        Dragon      8
#        Staff      47
#        Tome        7
# Green  Axe        91
#        Beast       8
#        Bow        12
#        Dagger      6
#        Dragon     10
#        Tome       53
# Red    Beast       8
#        Bow         8
#        Dagger      8
#        Dragon     14
#        Sword     123
#        Tome       56
# dtype: int64

# %%
dfn.groupby(by = ["Color", "Weapon"]).size()
# Out:
# Color  Weapon
# Blue   Beast       7
#        Bow         9
#        Dagger      5
#        Dragon     15
#        Lance     113
#        Tome       57
# Gray   Axe         1
#        Beast      10
#        Bow        49
#        Dagger     39
#        Dragon      8
#        Staff      47
#        Tome        7
# Green  Axe        90
#        Beast       8
#        Bow        12
#        Dagger      6
#        Dragon     10
#        Tome       53
# Red    Beast       8
#        Bow         8
#        Dagger      8
#        Dragon     14
#        Sword     123
#        Tome       56
# dtype: int64

# %% [markdown]
# The counts almost match up, but there is an instance where under Gray units, there is an axe user. This may not seem like much, but in the game, axe users have always been green up until now. This required a little double checking to see who it was, and after seeing who it was, we saw that there was an error when running the script for the general character page. We changed the color column to reflect this. To fix this, we will use the color column from GamePedia.

# %%
dfn[(dfn["Color"] == "Gray") & (dfn["Weapon"] == "Axe")]
# Out:
#              Name Color Weapon MoveCode      Rarities  HP Atk Spd Def Res  \
# 732  Summer Innes  Gray    Axe      316  stars-5-Star  42  33  37  30  20
#
#     Total  Tier                         Title  Refines  Personal Weapon  \
# 732   162   5.0  Summer Innes - Flawless Form     True            False
#
#      Legendary/Mythic                          Origin    Duo  \
# 732             False  Fire Emblem: The Sacred Stones  False
#
#                                                  Image Movement  \
# 732  https://gamepress.gg/feheroes/sites/fireemblem...   Flying
#
#                                                Banners  Number of Banners
# 732  [Summer's Arrival, Legendary Hero: Hríd - Icy ...                  3

# %%
# sanity check to change colors
dfn["Color"] = col2

# %% [markdown]
# Another such important trait is whether a character is a particular unit class called a "refresher", which allows said character to "refresh" a character, granting them another move on your turn. This is quite the offensive boon, as giving your strongest character the opportunity to attack not one but TWO characters in your turn can turn the tide of battle in an instant.
#
# In the game, there are two basic refreshing skills: dance, and sing. Thus, we will scrape for all characters who are capable of using either skill.

# %%
# to get list of refresher characters

refresh = []
dsurls = ["https://gamepress.gg/feheroes/command-skills/dance",
         "https://gamepress.gg/feheroes/command-skills/sing"]

ser = Service("./chromedriver")
op = webdriver.ChromeOptions()
# below two lines allow us to initiate "Headless Mode", which means that selenium works silently
op.add_argument('--headless')
op.add_argument('--disable-gpu')
brow = webdriver.Chrome(service=ser, options=op)
for lin in dsurls:
    brow.get(lin)
    ddata = brow.page_source
    dsoup = BeautifulSoup(ddata, "html.parser")
    since = dsoup.find("div", id = "block-gamepressbase-content")
    char = since.find("div", {"class": "views-element-container"}).findAll("a")
    for it in char[1::2]:
        refresh.append(it.get_text())
brow.quit()

# %%
# creates a column with a binary indicator of whether a unit is a refresher
ref = dfn["Name"].apply(lambda x: x in refresh)
dfn2 = dfn.copy()
dfn2["Refresher"] = ref

# %%
# goes through the 'Rarities' column to create two features: one for how the character is obtained in the game, and one for actual rarity

rar = []
ob = []
for row in dfn2["Rarities"]:
    st = []
    a = row.split("_")[0]
    if "Story" in row:
        ob.append("Story")
    elif "Grand_Hero_Battle" in row:
        ob.append("GHB")
    elif "Tempest_Trials" in row:
        ob.append("TT")
    elif "Enemy_Only" in row:
        ob.append("Enemy-Only")
    elif "Legacy" in row:
        ob.append("Legacy")
    else:
        ob.append("NA")
    for i in a.split("-"):
        if "2" in i or "3" in i or "4" in i or "5" in i:
            st.append(i)
    rar.append(st)

# %%
dfn2["Stars"] = rar
dfn2["Obtain"] = ob

# %% [markdown]
# If we look carefully at the data, we will notice that some of the characters are missing origin information. Until Gamepress.gg fixes this, we will resort to doing this manually.

# %%
dfn[dfn["Origin"] == "None"]
# Out:
#                      Name  Color  Weapon MoveCode                   Rarities  \
# 236  Legendary Byleth (M)  Green    Tome      331               stars-5-Star
# 445          Brave Lucina   Blue   Lance      331                   5_Legacy
# 463     Performing Olivia   Gray  Dagger      331               stars-5-Star
# 583      Halloween Dorcas  Green     Axe      326  4-5_Event:_Tempest_Trials
# 630                Keaton    Red   Beast      331               stars-5-Star
# 631              Velouria   Gray   Beast      331               stars-5-Star
# 632                 Kaden  Green   Beast      306               stars-5-Star
# 675        New Year Azura  Green     Axe      316               stars-5-Star
# 686           Hector (LA)  Green     Axe      326               stars-5-Star
# 687              Lyn (LA)   Blue    Tome      326               stars-5-Star
# 693                  Lute   Blue    Tome      331                   5_Legacy
# 696      Halloween Sakura   Gray  Dagger      331               stars-5-Star
# 699        Halloween Nowi    Red    Tome      316               stars-5-Star
#
#      HP Atk Spd Def Res Total  Tier                                   Title  \
# 236  40  39  41  25  21   166   1.0  Legendary Byleth (M) - The Fódlan Star
# 445  41  34  36  27  19   157   1.0           Brave Lucina - Brave Princess
# 463  34  28  34  16  28   140   3.0     Performing Olivia - Festival Dancer
# 583  49  41  25  37  21   173   4.0      Halloween Dorcas - Pumpkin Smasher
# 630  45  41  24  38  19   167   3.0               Keaton - Lupine Collector
# 631  40  35  37  33  23   168   1.0                     Velouria - Wolf Cub
# 632  38  32  36  25  25   156   2.0                Kaden - Kitsune Braggart
# 675  37  30  35  22  26   150   3.0     New Year Azura - Celebratory Spirit
# 686  50  38  21  40  24   173   2.0        Hector (LA) - Just Here to Fight
# 687  37  31  36  27  34   165   3.0               Lyn (LA) - Wind's Embrace
# 693  33  36  32  16  34   151   3.0                          Lute - Prodigy
# 696  33  32  34  14  34   147   4.0      Halloween Sakura - Gentle Nekomata
# 699  34  34  32  20  27   147   3.0          Halloween Nowi - Eternal Witch
#
#      Refines  Personal Weapon  Legendary/Mythic Origin    Duo  \
# 236    False             True              True   None  False
# 445     True             True             False   None  False
# 463     True            False             False   None  False
# 583     True            False             False   None  False
# 630    False             True             False   None  False
# 631    False             True             False   None  False
# 632    False             True             False   None  False
# 675     True            False             False   None  False
# 686     True             True             False   None  False
# 687     True            False             False   None  False
# 693     True             True             False   None  False
# 696    False            False             False   None  False
# 699     True             True             False   None  False
#
#                                                  Image  Movement  \
# 236  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 445  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 463  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 583  https://gamepress.gg/feheroes/sites/fireemblem...   Armored
# 630  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 631  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 632  https://gamepress.gg/feheroes/sites/fireemblem...   Cavalry
# 675  https://gamepress.gg/feheroes/sites/fireemblem...    Flying
# 686  https://gamepress.gg/feheroes/sites/fireemblem...   Armored
# 687  https://gamepress.gg/feheroes/sites/fireemblem...   Armored
# 693  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 696  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 699  https://gamepress.gg/feheroes/sites/fireemblem...    Flying
#
#                                                Banners  Number of Banners
# 236  [Legendary Hero (Byleth: The Fódlan Light), My...                  3
# 445  [Weekly Revival 19, Weekly Revival 6, Year-One...                  9
# 463  [Performing Arts, Ephraim Legendary Lord, Perf...                  3
# 583                                                 []                  0
# 630                             [Kitsune and Wolfskin]                  1
# 631  [Heroes with Close Defense, Mythic Hero (Naga:...                  3
# 632  [Legendary Hero (Julia: Crusader of Light), Ki...                  2
# 675  [Happy New Year!, Legendary Hero, New Years Ba...                  3
# 686     [Love Abounds, Marth: Hero-King, Love Abounds]                  3
# 687  [Love Abounds, Legendary Hero: Hector - Marque...                  3
# 693  [Tempest Trials+ (June 2020), New Power Octobe...                  6
# 696  [Trick or Defeat 2019, Trick or Defeat!, Legen...                  4
# 699  [Trick or Defeat 2019, Trick or Defeat!, Legen...                  4

# %%
dfn2[dfn2["Name"] == "Hatari Azura"]
# Out:
#              Name  Color Weapon MoveCode      Rarities  HP Atk Spd Def Res  \
# 267  Hatari Azura  Green   Tome      306  stars-5-Star  37  37  39  16  23
#
#     Total  Tier                       Title  Refines  Personal Weapon  \
# 267   152  None  Hatari Azura - Hatari Duet    False             True
#
#      Legendary/Mythic                                             Origin  \
# 267             False  [Fire Emblem: Path of Radiance, Fire Emblem Fa...
#
#       Duo                                              Image Movement  \
# 267  True  https://gamepress.gg/feheroes/sites/fireemblem...  Cavalry
#
#                 Banners  Number of Banners  Refresher Stars Obtain
# 267  [Of Lost Kingdoms]                  1       True   [5]     NA

# %%
#dfn2[dfn2["Name"] == "Brave Lucina"].Origin = "Fire Emblem: Awakening"
dfn2.loc[dfn2["Name"] == "Brave Lucina", "Origin"] = "Fire Emblem: Awakening"
dfn2.loc[dfn2["Name"] == "Halloween Dorcas", "Origin"] = "Fire Emblem: The Blazing Blade"
dfn2.loc[dfn2["Name"] == "Halloween Nowi", "Origin"] = "Fire Emblem: Awakening"
dfn2.loc[dfn2["Name"] == "Halloween Sakura", "Origin"] = "Fire Emblem Fates"
dfn2.loc[dfn2["Name"] == "Hector (LA)", "Origin"] = "Fire Emblem: The Blazing Blade"
dfn2.loc[dfn2["Name"] == "Kaden", "Origin"] = "Fire Emblem Fates"
dfn2.loc[dfn2["Name"] == "Keaton", "Origin"] = "Fire Emblem Fates"
dfn2.loc[dfn2["Name"] == "Lute", "Origin"] = "Fire Emblem: The Sacred Stones"
dfn2.loc[dfn2["Name"] == "Lyn (LA)", "Origin"] = "Fire Emblem: The Blazing Blade"
dfn2.loc[dfn2["Name"] == "New Year Azura", "Origin"]= "Fire Emblem Fates"
dfn2.loc[dfn2["Name"] == "Performing Olivia", "Origin"] = "Fire Emblem: Awakening"
dfn2.loc[dfn2["Name"] == "Velouria", "Origin"] = "Fire Emblem Fates"
dfn2.loc[dfn2["Name"] == "Legendary Byleth (M)", "Origin"] = "Fire Emblem: Three Houses"

# %% [markdown]
# As the website gets updated with new characters, we will notice that not all of the characters have an assigned Tier. Let's run the script below to see which of the characters fall into this category. The below scripts will change the value so that it is easier to visualize when grouping.

# %%
dfn2[dfn2["Tier"].isnull() == True]
# Out:
#               Name  Color  Weapon MoveCode                   Rarities  HP Atk  \
# 267   Hatari Azura  Green    Tome      306               stars-5-Star  37  37
# 268   Hatari Karla   Blue   Lance      331               stars-5-Star  41  40
# 269  Hatari Nailah    Red   Beast      331               stars-5-Star  40  39
# 270    Hatari Xane   Gray   Staff      331                        4-5  47  30
# 762    Hatari Deen   Gray  Dagger      306  4-5_Event:_Tempest_Trials  43  36
#
#     Spd Def Res Total  Tier                              Title  Refines  \
# 267  39  16  23   152   NaN         Hatari Azura - Hatari Duet    False
# 268  42  31  28   182   NaN  Hatari Karla - Sun-Piercing Steel    False
# 269  43  35  25   182   NaN    Hatari Nailah - Hatari Scorcher    False
# 270  36  23  35   171   NaN        Hatari Xane - Desert Mirage    False
# 762  39  27  23   168   NaN     Hatari Deen - Bladed Sandstorm     True
#
#      Personal Weapon  Legendary/Mythic                              Origin  \
# 267             True             False       Fire Emblem: Path of Radiance
# 268             True             False      Fire Emblem: The Blazing Blade
# 269             True             False           Fire Emblem: Radiant Dawn
# 270            False             False  Fire Emblem: Mystery of the Emblem
# 762            False             False                  Fire Emblem Echoes
#
#        Duo                                              Image  Movement  \
# 267   True  https://gamepress.gg/feheroes/sites/fireemblem...   Cavalry
# 268  False  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 269  False  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 270  False  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 762  False  https://gamepress.gg/feheroes/sites/fireemblem...   Cavalry
#
#                 Banners  Number of Banners  Refresher   Stars Obtain
# 267  [Of Lost Kingdoms]                  1       True     [5]     NA
# 268  [Of Lost Kingdoms]                  1      False     [5]     NA
# 269  [Of Lost Kingdoms]                  1      False     [5]     NA
# 270  [Of Lost Kingdoms]                  1      False  [4, 5]     NA
# 762                  []                  0      False  [4, 5]     TT

# %%
dfn2["Tier"] = dfn2["Tier"].fillna("None")

# %%
dfn2.groupby(by = "Tier").size()
# Out:
# Tier
# 1.0      74
# 2.0     194
# 3.0     217
# 4.0     158
# 5.0     115
# None      5
# dtype: int64

# %%
# to get release date of characters
ser = Service("./chromedriver")
op = webdriver.ChromeOptions()
# below two lines allow us to initiate "Headless Mode", which means that selenium works silently
op.add_argument('--headless')
op.add_argument('--disable-gpu')
browser = webdriver.Chrome(service=ser, options=op)
r_list = ("https://feheroes.fandom.com/wiki/List_of_Heroes")
browser.get(r_list)
releaseData = browser.page_source
browser.close()
release_soup = BeautifulSoup(releaseData, 'html.parser')

# %%
release_table = release_soup.find_all('tr', attrs={'class':'hero-filter-element'})

# %%
# this function adjusts the title so that it matches with the GamePress data, allowing
# for merging

def title_fix(title):
    print(title)
    title_a, title_b = title.split(":")
    title_a = title_a.split(" ")[-1]
    return title_a + " :" + title_b

# title_fix(release_table[0].find_all('td')[1].text)

#.text.split(':')[0].split(" ")[-1]
# Out:
# Abel: The Panther
# 'Abel: The Panther'

# %%
release_data_dict = {}
origin_data_dict = {}

# based on scraping that shows differences in used titles - this dictionary fixes the following needed changes
    # Tethys: typo ("Dancer")
    # Canas: "Wisdom Seeker in GPedia"
    # Hatari - no info
    # Niles - the word "be" is capitalized in Gpedia
    # Eliwood - Marquess Pherae in GPedia
    # Winter Tharja - quotes around "Normal Girl" in Gpedia
title_change_dict = {"Niles - Cruel to Be Kind": "Niles - Cruel to be Kind", 
                     "Eliwood - Marquess Pherae": "Eliwood - Marquess of Pherae",
                    'Tharja - "Normal Girl"': "Tharja - Normal Girl",
                    "Canas - Wisdom Seeker": "Canas - Seeker of Wisdom"}

for char in release_table:
    title = char.findAll("td")[1].text
    title = title.replace(":", " -")
    title = re.sub(r'\([^)]*\)', '', title)
    if title in title_change_dict.keys():
        title = title_change_dict[title]
    release_date = char.findAll("td")[7].text
    origin = char.findAll("td")[2].text
    release_data_dict[title] = release_date
    origin_data_dict[title] = origin

# %%
dfn2[dfn2["Name"].str.contains("\(")]
# Out:
#                        Name  Color  Weapon MoveCode  \
# 52        Summer Byleth (F)    Red    Tome      316
# 57                 Kris (M)    Red   Sword      331
# 60                 Kris (F)   Blue   Lance      331
# 79        Fallen Corrin (M)   Blue  Dragon      331
# 100    Legendary Corrin (F)   Gray  Dragon      331
# 116              Byleth (F)    Red   Sword      331
# 117              Byleth (M)    Red   Sword      331
# 134       Fallen Corrin (F)   Gray  Dragon      331
# 136     Fallen Tiki (Young)   Gray  Dragon      326
# 143             Naga (Unit)   Blue  Dragon      316
# 185           Sirius (Unit)   Blue   Lance      306
# 236    Legendary Byleth (M)  Green    Tome      331
# 247     Halloween Robin (M)   Gray  Dragon      326
# 256    Legendary Byleth (F)   Blue    Tome      331
# 284        Ninja Corrin (F)  Green    Tome      306
# 287        Ninja Corrin (M)   Blue   Lance      331
# 306  Selena (Sacred Stones)   Blue    Tome      306
# 333     Halloween Robin (F)  Green  Dragon      316
# 366       Fallen Morgan (M)    Red    Tome      331
# 367       Fallen Morgan (F)  Green     Axe      316
# 414        Summer Robin (F)   Blue   Lance      331
# 415     Summer Tiki (Adult)  Green     Axe      331
# 449       Summer Corrin (F)   Blue    Tome      316
# 500               Robin (F)  Green    Tome      331
# 506            Tiki (Young)    Red  Dragon      331
# 510               Robin (M)   Blue    Tome      331
# 517              Corrin (M)    Red   Sword      331
# 518              Corrin (F)   Blue  Dragon      331
# 533          Selena (Fates)    Red   Sword      331
# 540            Tiki (Adult)    Red  Dragon      331
# 578       Adrift Corrin (F)  Green  Dragon      331
# 588       Adrift Corrin (M)   Blue  Dragon      331
# 592           Azura (Young)  Green    Tome      331
# 600  Legendary Tiki (Young)   Blue  Dragon      326
# 668             Olivia (YT)    Red   Sword      316
# 674     New Year Corrin (M)   Gray     Bow      331
# 682             Eirika (SM)    Red    Tome      306
# 685             Lilina (LA)  Green    Tome      306
# 686             Hector (LA)  Green     Axe      326
# 687                Lyn (LA)   Blue    Tome      326
# 688                Roy (LA)   Gray     Bow      306
# 689            Eliwood (LA)   Blue   Lance      326
# 715        Fallen Robin (M)  Green  Dragon      326
# 726               Nino (SF)  Green    Tome      316
# 736     Summer Tiki (Young)    Red  Dragon      316
# 745              Morgan (F)   Blue    Tome      316
# 746              Morgan (M)    Red    Tome      331
# 757               stars-5-Star  40  30  34  33  26   163  3.0
# 759               stars-5-Star  37  32  35  17  29   150  2.0
# 760      3-4_Grand_Hero_Battle  40  31  33  31  29   164  3.0
#
#                                          Title  Refines  Personal Weapon  \
# 52         Summer Byleth (F) - Fell Star's Duo    False             True
# 57                     Kris (M) - Unknown Hero    False             True
# 60                      Kris (F) - Unsung Hero    False             True
# 79        Fallen Corrin (M) - Bloodbound Beast    False             True
# 100       Legendary Corrin (F) - Child of Dusk    False             True
# 116              Byleth (F) - Proven Professor    False             True
# 117              Byleth (M) - Tested Professor    False             True
# 134           Fallen Corrin (F) - Wailing Soul    False             True
# 136        Fallen Tiki (Young) - Torpid Dragon    False             True
# 143              Naga (Unit) - Dragon Divinity    False            False
# 185          Sirius (Unit) - Mysterious Knight    False             True
# 236     Legendary Byleth (M) - The Fódlan Star    False             True
# 247   Halloween Robin (M) - Fall Reincarnation    False             True
# 256    Legendary Byleth (F) - The Fódlan Light    False             True
# 284     Ninja Corrin (F) - Nightfall Ninja Act    False             True
# 287      Ninja Corrin (M) - Daylight Ninja Act    False            False
# 306         Selena (Sacred Stones) - Fluorspar    False             True
# 333          Halloween Robin (F) - Fall Vessel    False             True
# 366         Fallen Morgan (M) - Fated Darkness    False             True
# 367       Fallen Morgan (F) - Devoted Darkness    False             True
# 414       Summer Robin (F) - Seaside Tactician     True            False
# 415      Summer Tiki (Adult) - Summering Scion     True            False
# 449      Summer Corrin (F) - Novice Vacationer     True            False
# 500              Robin (F) - Mystery Tactician     True             True
# 506                Tiki (Young) - Dragon Scion     True             True
# 510                 Robin (M) - High Deliverer     True             True
# 517                Corrin (M) - Fateful Prince     True             True
# 518              Corrin (F) - Fateful Princess     True             True
# 533               Selena (Fates) - Cutting Wit     True             True
# 540                Tiki (Adult) - Naga's Voice     True             True
# 578         Adrift Corrin (F) - Dream Princess     True             True
# 588           Adrift Corrin (M) - Dream Prince     True             True
# 592           Azura (Young) - Young Songstress    False             True
# 600  Legendary Tiki (Young) - Legendary Dragon     True             True
# 668              Olivia (YT) - Sky-High Dancer    False             True
# 674   New Year Corrin (M) - Enjoying Tradition     True            False
# 682               Eirika (SM) - Anamnesis Lady     True             True
# 685               Lilina (LA) - Blush of Youth    False            False
# 686           Hector (LA) - Just Here to Fight     True             True
# 687                  Lyn (LA) - Wind's Embrace     True            False
# 688                  Roy (LA) - Youthful Gifts     True            False
# 689                Eliwood (LA) - Devoted Love     True            False
# 715      Fallen Robin (M) - Fell Reincarnation     True             True
# 726                    Nino (SF) - Pale Flower     True             True
# 736      Summer Tiki (Young) - Beachside Scion     True             True
# 745                Morgan (F) - Lass from Afar     True             True
# 746                 Morgan (M) - Lad from Afar     True             True
# 753          Legendary Robin (F) - Fell Vessel     True             True
# 754           Reinhardt (WT) - Thunder's Sword     True             True
# 755              Olwen (WT) - Righteous Knight     True             True
# 757                 Kana (F) - Dragon Princess     True             True
# 759             Hinoka (WF) - Blue Sky Warrior     True             True
# 760                    Kana (M) - Dragon Spawn     True             True
#
#      Legendary/Mythic                                             Origin  \
# 52              False                          Fire Emblem: Three Houses
# 247      False     [5]      NA
# 256      False     [5]      NA
# 284      False     [5]      NA
# 287      False  [4, 5]      NA
# 306      False     [5]      NA
# 333      False     [5]      NA
# 366      False     [5]      NA
# 367      False     [5]      NA
# 414      False     [5]      NA
# 415      False     [5]      NA
# 449      False     [5]      NA
# 500      False  [2, 3]     GHB
# 506      False     [5]  Legacy
# 510      False  [3, 4]      NA
# 517      False  [3, 4]      NA
# 518      False  [3, 4]      NA
# 533      False  [3, 4]      NA
# 540      False  [3, 4]      NA
# 578      False     [5]      NA
# 588      False     [5]      NA
# 592       True  [4, 5]      TT
# 600      False     [5]      NA
# 668       True     [5]      NA
# 674      False  [4, 5]      TT
# 682      False     [5]      NA
# 685      False     [5]      NA
# 686      False     [5]      NA
# 687      False     [5]      NA
# 688      False     [5]      NA
# 689      False  [4, 5]      TT
# 715      False     [5]      NA
# 726      False     [5]      NA
# 736      False     [5]      NA
# 745      False     [5]      NA
# 746      False  [3, 4]      NA
# 753      False     [5]      NA
# 754      False     [5]      NA
# 755      False     [5]  Legacy
# 757      False     [5]      NA
# 759      False     [5]      NA
# 760      False  [3, 4]     GHB

# %%
# (YT), (LA), (SF), (WT), (WF), (Unit)

# %%
# a typo found in Gamepress's data
dfn2.loc[dfn2["Name"] == "Tethys", "Title"] = "Tethys - Beloved Dancer"

# %%
dfn3 = dfn2.copy()

def title_fix(title):
    to_ignore = ["Flame Emperor", "Black Knight", "Death Knight"]
    title_a, title_b = title.split(" -")
    if title_a in to_ignore:
        return title_a + " -" + title_b
    else:
        title_a = title_a.split(" ")[-1]
    return title_a + " -" + title_b

dfn3['Title'] = dfn3['Title'].apply(lambda x: re.sub(r'\([^)]*\) ', '', x)).apply(title_fix)
# split Title into two by the '-'. split the first half by space

release_df = pd.DataFrame.from_dict(release_data_dict, orient = "index", columns = ["Release Date"])
dfn3 = pd.merge(dfn3, release_df, left_on = "Title", right_index = True, how = "left")
origin_df = pd.DataFrame.from_dict(origin_data_dict, orient = "index", columns = ["Origin - GPedia"])
dfn3 = pd.merge(dfn3, origin_df, left_on = "Title", right_index = True, how = "left")

# %%
dfn2[dfn2["Name"].str.contains("\(")]
# Out:
#                        Name  Color  Weapon MoveCode  \
# 52        Summer Byleth (F)    Red    Tome      316
# 57                 Kris (M)    Red   Sword      331
# 60                 Kris (F)   Blue   Lance      331
# 79        Fallen Corrin (M)   Blue  Dragon      331
# 100    Legendary Corrin (F)   Gray  Dragon      331
# 116              Byleth (F)    Red   Sword      331
# 117              Byleth (M)    Red   Sword      331
# 134       Fallen Corrin (F)   Gray  Dragon      331
# 136     Fallen Tiki (Young)   Gray  Dragon      326
# 143             Naga (Unit)   Blue  Dragon      316
# 185           Sirius (Unit)   Blue   Lance      306
# 236    Legendary Byleth (M)  Green    Tome      331
# 247     Halloween Robin (M)   Gray  Dragon      326
# 256    Legendary Byleth (F)   Blue    Tome      331
# 284        Ninja Corrin (F)  Green    Tome      306
# 287        Ninja Corrin (M)   Blue   Lance      331
# 306  Selena (Sacred Stones)   Blue    Tome      306
# 333     Halloween Robin (F)  Green  Dragon      316
# 674                                                 []                  0
# 682  [Ephraim and Myrrh's Battle, Heroes with Swift...                  4
# 685  [Love Abounds, Legendary Heroes Lucina, Love A...                  3
# 686     [Love Abounds, Marth: Hero-King, Love Abounds]                  3
# 687  [Love Abounds, Legendary Hero: Hector - Marque...                  3
# 688  [Love Abounds, Legendary Hero: Hector - Marque...                  3
# 689                                                 []                  0
# 715  [Destructive Forces, Eirika: Graceful Resolve,...                  5
# 726  [Tempest Trials December 2019, Children's Day ...                  6
# 736  [A Sketchy Summer, Legendary Hero: Azura - Val...                  3
# 745  [Morgan and Morgan's Battle, War of the Tactic...                  6
# 746     [Morgan and Morgan's Battle, The Branded King]                  2
# 753  [Legendary Hero (Seliph: Scion of Light), Myth...                 15
# 754  [Heroes with Vantage, Ishtar & Reinhardt, Mart...                  5
# 755  [New Power (March 2020), Healing Skills, World...                  3
# 757  [Heroes with Fierce Stance September 2019, Leg...                  5
# 759  [Voting Gauntlet August 2019, Heroes with Flie...                  7
# 760                                                 []                  0
#
#      Refresher   Stars  Obtain
# 52       False     [5]      NA
# 57       False     [5]      NA
# 60       False     [5]      NA
# 79       False     [5]      NA
# 100      False     [5]      NA
# 116      False     [5]      NA
# 117      False     [5]      NA
# 134      False     [5]      NA
# 136      False     [5]      NA
# 143      False     [5]      NA
# 185      False     [5]      NA
# 236      False     [5]      NA
# 247      False     [5]      NA
# 256      False     [5]      NA
# 284      False     [5]      NA
# 287      False  [4, 5]      NA
# 306      False     [5]      NA
# 333      False     [5]      NA
# 366      False     [5]      NA
# 367      False     [5]      NA
# 414      False     [5]      NA
# 415      False     [5]      NA
# 449      False     [5]      NA
# 500      False  [2, 3]     GHB
# 506      False     [5]  Legacy
# 510      False  [3, 4]      NA
# 517      False  [3, 4]      NA
# 518      False  [3, 4]      NA
# 533      False  [3, 4]      NA
# 540      False  [3, 4]      NA
# 578      False     [5]      NA
# 588      False     [5]      NA
# 592       True  [4, 5]      TT
# 600      False     [5]      NA
# 668       True     [5]      NA
# 674      False  [4, 5]      TT
# 682      False     [5]      NA
# 685      False     [5]      NA
# 686      False     [5]      NA
# 687      False     [5]      NA
# 688      False     [5]      NA
# 689      False  [4, 5]      TT
# 715      False     [5]      NA
# 726      False     [5]      NA
# 736      False     [5]      NA
# 745      False     [5]      NA
# 746      False  [3, 4]      NA
# 753      False     [5]      NA
# 754      False     [5]      NA
# 755      False     [5]  Legacy
# 757      False     [5]      NA
# 759      False     [5]      NA
# 760      False  [3, 4]     GHB

# %%
pd.set_option('display.max_columns', None)
dfn3.head()
# Out:
#             Name  Color  Weapon MoveCode               Rarities  HP Atk Spd  \
# 0        Sharena   Blue   Lance      331           4_Star_Story  43  32  32
# 1  Flame Emperor  Green     Axe      326  3-4_Grand_Hero_Battle  50  40  25
# 2           Rath  Green     Bow      306                    3-4  41  33  35
# 3          Fiora   Blue   Lance      316           stars-5-Star  38  32  38
# 4          Leila   Gray  Dagger      331           stars-5-Star  40  36  41
#
#   Def Res Total Tier                           Title  Refines  \
# 0  29  22   158  5.0      Sharena - Princess of Askr     True
# 1  37  26   178  4.0  Flame Emperor - Bringer of War     True
# 2  23  24   156  3.0            Rath - Wolf of Sacae     True
# 3  21  37   166  5.0        Fiora - Airborne Warrior     True
# 4  23  26   166  2.0         Leila - Rose amid Fangs    False
#
#    Personal Weapon  Legendary/Mythic                          Origin    Duo  \
# 0             True             False              Fire Emblem Heroes  False
# 1            False             False       Fire Emblem: Three Houses  False
# 2            False             False  Fire Emblem: The Blazing Blade  False
# 3            False             False  Fire Emblem: The Blazing Blade  False
# 4             True             False  Fire Emblem: The Blazing Blade  False
#
#                                                Image  Movement  \
# 0  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 1  https://gamepress.gg/feheroes/sites/fireemblem...   Armored
# 2  https://gamepress.gg/feheroes/sites/fireemblem...   Cavalry
# 3  https://gamepress.gg/feheroes/sites/fireemblem...    Flying
# 4  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
#
#             Banners  Number of Banners  Refresher   Stars Obtain Release Date  \
# 0                []                  0      False     [4]  Story   2017-02-02
# 1                []                  0      False  [3, 4]    GHB   2020-03-09
# 2  [The Dread Isle]                  1      False  [3, 4]     NA   2020-02-17
# 3  [The Dread Isle]                  1      False     [5]     NA   2020-02-17
# 4  [The Dread Isle]                  1      False     [5]     NA   2020-02-17
#
#                   Origin - GPedia
# 0              Fire Emblem Heroes
# 1       Fire Emblem: Three Houses
# 2  Fire Emblem: The Blazing Blade
# 3  Fire Emblem: The Blazing Blade
# 4  Fire Emblem: The Blazing Blade

# %%
dfn3[dfn3["Release Date"].isnull()]
# Tethys: typo ("Dancer")
# Canas: "Wisdom Seeker in GPedia"
# Hatari - no info
# Niles - the word "be" is capitalized in Gpedia
# Eliwood - Marquess Pherae in GPedia
# Winter Tharja - quotes around "Normal Girl" in Gpedia
# Out:
#               Name  Color  Weapon MoveCode                   Rarities  HP Atk  \
# 267   Hatari Azura  Green    Tome      306               stars-5-Star  37  37
# 268   Hatari Karla   Blue   Lance      331               stars-5-Star  41  40
# 269  Hatari Nailah    Red   Beast      331               stars-5-Star  40  39
# 270    Hatari Xane   Gray   Staff      331                        4-5  47  30
# 762    Hatari Deen   Gray  Dagger      306  4-5_Event:_Tempest_Trials  43  36
#
#     Spd Def Res Total  Tier                       Title  Refines  \
# 267  39  16  23   152  None         Azura - Hatari Duet    False
# 268  42  31  28   182  None  Karla - Sun-Piercing Steel    False
# 269  43  35  25   182  None    Nailah - Hatari Scorcher    False
# 270  36  23  35   171  None        Xane - Desert Mirage    False
# 762  39  27  23   168  None     Deen - Bladed Sandstorm     True
#
#      Personal Weapon  Legendary/Mythic  \
# 267             True             False
# 268             True             False
# 269             True             False
# 270            False             False
# 762            False             False
#
#                                                 Origin    Duo  \
# 267  [Fire Emblem: Path of Radiance, Fire Emblem Fa...   True
# 268                     Fire Emblem: The Blazing Blade  False
# 269                          Fire Emblem: Radiant Dawn  False
# 270                 Fire Emblem: Mystery of the Emblem  False
# 762                                 Fire Emblem Echoes  False
#
#                                                  Image  Movement  \
# 267  https://gamepress.gg/feheroes/sites/fireemblem...   Cavalry
# 268  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 269  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 270  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 762  https://gamepress.gg/feheroes/sites/fireemblem...   Cavalry
#
#                 Banners  Number of Banners  Refresher   Stars Obtain  \
# 267  [Of Lost Kingdoms]                  1       True     [5]     NA
# 268  [Of Lost Kingdoms]                  1      False     [5]     NA
# 269  [Of Lost Kingdoms]                  1      False     [5]     NA
# 270  [Of Lost Kingdoms]                  1      False  [4, 5]     NA
# 762                  []                  0      False  [4, 5]     TT
#
#     Release Date Origin - GPedia
# 267          NaN             NaN
# 268          NaN             NaN
# 269          NaN             NaN
# 270          NaN             NaN
# 762          NaN             NaN

# %%
heroes = dfn3
#heroes = heroes[heroes["Obtain"] != "Enemy-Only"]

# %%
heroes[["HP", "Atk", "Spd", "Def", "Res"]] = heroes[["HP", "Atk", "Spd", "Def", "Res"]].apply(pd.to_numeric)

# %% [markdown]
# ## Save to CSV
#
# The cell below will save the data that we've scraped and processed into a .csv file that can be used for future analysis.

# %%
# set last_update variable to the current month and year
last_update = time.strftime("%m-%y")
heroes.to_excel("hero_data_" + last_update + ".xlsx", encoding='utf-8', index=False)
heroes.to_csv("hero_data_" + last_update + ".csv", encoding='utf-8', index=False)
#heroes["Name"].to_excel("tier_list.xlsx", encoding='utf-8', header = True)

# %%
heroes = pd.read_csv('./hero_data_' + last_update + '.csv')
heroes.head()
# Out:
#             Name  Color  Weapon  MoveCode               Rarities  HP  Atk  \
# 0        Sharena   Blue   Lance       331           4_Star_Story  43   32
# 1  Flame Emperor  Green     Axe       326  3-4_Grand_Hero_Battle  50   40
# 2           Rath  Green     Bow       306                    3-4  41   33
# 3          Fiora   Blue   Lance       316           stars-5-Star  38   32
# 4          Leila   Gray  Dagger       331           stars-5-Star  40   36
#
#    Spd  Def  Res  Total Tier                           Title  Refines  \
# 0   32   29   22    158  5.0      Sharena - Princess of Askr     True
# 1   25   37   26    178  4.0  Flame Emperor - Bringer of War     True
# 2   35   23   24    156  3.0            Rath - Wolf of Sacae     True
# 3   38   21   37    166  5.0        Fiora - Airborne Warrior     True
# 4   41   23   26    166  2.0         Leila - Rose amid Fangs    False
#
#    Personal Weapon  Legendary/Mythic                          Origin    Duo  \
# 0             True             False              Fire Emblem Heroes  False
# 1            False             False       Fire Emblem: Three Houses  False
# 2            False             False  Fire Emblem: The Blazing Blade  False
# 3            False             False  Fire Emblem: The Blazing Blade  False
# 4             True             False  Fire Emblem: The Blazing Blade  False
#
#                                                Image  Movement  \
# 0  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
# 1  https://gamepress.gg/feheroes/sites/fireemblem...   Armored
# 2  https://gamepress.gg/feheroes/sites/fireemblem...   Cavalry
# 3  https://gamepress.gg/feheroes/sites/fireemblem...    Flying
# 4  https://gamepress.gg/feheroes/sites/fireemblem...  Infantry
#
#               Banners  Number of Banners  Refresher       Stars Obtain  \
# 0                  []                  0      False       ['4']  Story
# 1                  []                  0      False  ['3', '4']    GHB
# 2  ['The Dread Isle']                  1      False  ['3', '4']    NaN
# 3  ['The Dread Isle']                  1      False       ['5']    NaN
# 4  ['The Dread Isle']                  1      False       ['5']    NaN
#
#   Release Date                 Origin - GPedia
# 0   2017-02-02              Fire Emblem Heroes
# 1   2020-03-09       Fire Emblem: Three Houses
# 2   2020-02-17  Fire Emblem: The Blazing Blade
# 3   2020-02-17  Fire Emblem: The Blazing Blade
# 4   2020-02-17  Fire Emblem: The Blazing Blade

# %% [markdown]
# ## Conclusion

# %% [markdown]
# At this point, we have successfully scraped data from a host website in a proper way, extracting important information and processing data into a clean dataframe. From here, we can do multiple things with this data, such as create a model for predicting the labeled tier of a unit, or perform exploratory data analysis on a specific set of characters.
